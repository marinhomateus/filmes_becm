# %%
import matplotlib.pyplot as mp
import numpy as np
import scipy.stats as sp
import seaborn as sns

uri = "https://raw.githubusercontent.com/marinhomateus/filmes_becm/master/dataset/ratings.csv"
notas = pd.read_csv(uri)

notas.columns = ['usuarioId', 'filmeId','nota','momento']


notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
mp.xlabel('Notas')
mp.ylabel('Frequência')
mp.title('Gráfico de Densidade')
mp.hist(notas.nota, color="0.55")
mp.show()

# %%
sns.displot(data=notas.nota, kind="kde")

# %% [markdown]
# Distribuição, densidade, moda, média, mediana, desvio padrao

# %%
notas.nota
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
media = round(np.mean(notas.nota), 1)

mediana = np.median(notas.nota)

moda = sp.mode(notas.nota).mode[0]

desviopadrao = round(np.std(notas.nota), 1)

print("Média: " , media, 
      "\nMediana: " , mediana, 
      "\nModa: " , moda, 
      "\nDesvio Padrão: " , desviopadrao, "\n")

print(notas.nota)
# Out:
# Média:  3.5
# Mediana:  3.5
# Moda:  4.0
# Desvio Padrão:  1.0
#
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64
